# %%
import cv2 as cv
import numpy as np

lower_blue = np.array([100,60,105])
upper_blue = np.array([180,255,255])
lower_green = np.array([50, 20,90])
upper_green = np.array([100, 255, 250])
lower_red = np.array([60, 140,200])
upper_red = np.array([180, 255, 255])
while(1):
    frame = cv.imread('/home/bhavya/Documents/vscode/python/AUV/2.png')
    image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
   
    blue_mask = cv.inRange(image, lower_blue, upper_blue)
    green_mask = cv.inRange(image, lower_green, upper_green)
    red_mask = cv.inRange(image, lower_red, upper_red)

    contours, hierarchy = cv.findContours(blue_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
    
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, a, b = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + a, y + b), (180, 0, 0), 2)
            cv.circle(frame, (((x, y)[0] + 31, (x + a, y + b)[1] + 42)), 2, (255, 255, 255),-1)
            cv.putText(frame, "blue color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(180, 0, 0))  

    contours, hierarchy = cv.findContours(green_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, a, b = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + a, y + b), (0, 255, 0), 2)
            cv.putText(frame, "green color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 255, 0)) 

    contours, hierarchy = cv.findContours(red_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, a, b = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + a, y + b), (0, 0, 255), 2)
            cv.putText(frame, "red color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 0, 255)) 


    
    cv.imshow("normal image", frame)
    
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cv.destroyAllWindows()

# %% [markdown]
# color salection

# %%
import cv2 as cv
import numpy as np

lower_red = np.array([40, 140,190])
upper_red = np.array([100, 255, 255])
while(1):
    frame = cv.imread('/home/bhavya/Pictures/task 1.png')
    image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
    red_mask = cv.inRange(image, lower_red, upper_red)
    
    
    cv.imshow("mask", red_mask)
    
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cv.destroyAllWindows()

# %% [markdown]
# Circles

# %%
import cv2 as cv
import numpy as np

lower_blue = np.array([100,60,100])
upper_blue = np.array([180,255,255])
lower_green = np.array([50, 20,90])
upper_green = np.array([80, 255, 255])
lower_red = np.array([60, 140,200])
upper_red = np.array([180, 255, 255])
while(1):
    frame = cv.imread('/home/bhavya/Pictures/t')
    image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
    blue_mask = cv.inRange(image, lower_blue, upper_blue)
    green_mask = cv.inRange(image, lower_green, upper_green)
    red_mask = cv.inRange(image, lower_red, upper_red)
    contours, hierarchy = cv.findContours(blue_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            center = y
            frame = cv.circle(frame, x, y, (180, 0, 0), 2)
            cv.putText(frame, "blue color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(180, 0, 0))  

    contours, hierarchy = cv.findContours(green_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, w, h = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv.putText(frame, "green color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 255, 0)) 

    contours, hierarchy = cv.findContours(red_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, w, h = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)
            cv.putText(frame, "red color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 0, 255)) 


    
    cv.imshow("normal image", frame)
    
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-1a9a2e7f39a5> in <module>
#      10 while(1):
#      11     frame = cv.imread('/home/bhavya/Pictures/t')
# ---> 12     image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
#      13     blue_mask = cv.inRange(image, lower_blue, upper_blue)
#      14     green_mask = cv.inRange(image, lower_green, upper_green)
#
# error: OpenCV(4.2.0) ../modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2 as cv
import numpy as np

vid = cv.VideoCapture('/home/bhavya/Pictures/task 1 video.mkv')
lower_blue = np.array([100,60,100])
upper_blue = np.array([180,255,255])
lower_green = np.array([50, 20,90])
upper_green = np.array([80, 255, 255])
lower_red = np.array([60, 140,200])
upper_red = np.array([180, 255, 255])
while(1):
    _, frame = vid.read()
    image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
   
    blue_mask = cv.inRange(image, lower_blue, upper_blue)
    green_mask = cv.inRange(image, lower_green, upper_green)
    red_mask = cv.inRange(image, lower_red, upper_red)

    contours, hierarchy = cv.findContours(blue_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, a, b = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + a, y + b), (180, 0, 0), 2)
            cv.putText(frame, "blue color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(180, 0, 0))  

    contours, hierarchy = cv.findContours(green_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, a, b = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + a, y + b), (0, 255, 0), 2)
            cv.putText(frame, "green color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 255, 0)) 

    contours, hierarchy = cv.findContours(red_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv.contourArea(contour)
        if(area > 300):
            x, y, a, b = cv.boundingRect(contour)
            frame = cv.rectangle(frame, (x, y), (x + a, y + b), (0, 0, 255), 2)
            cv.putText(frame, "red color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 0, 255)) 


    
    cv.imshow("normal image", frame)
    
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cv.destroyAllWindows()

# %% [markdown]
# mask for video

# %%
import cv2 as cv
import numpy as np

vid = cv.VideoCapture('/home/bhavya/Pictures/task 1 video.mkv')
lower_red = np.array([40, 140,190])
upper_red = np.array([100, 255, 255])
while(1):
    _, frame = vid.read()
    image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
    red_mask = cv.inRange(image, lower_red, upper_red)
    
    
    cv.imshow("mask", red_mask)
    
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

cv.destroyAllWindows()

# %% [markdown]
# witth center

# %%
import cv2 as cv
import numpy as np

lower_blue = np.array([100,60,100])
upper_blue = np.array([180,255,255])
lower_green = np.array([50, 20,90])
upper_green = np.array([80, 255, 255])
lower_red = np.array([60, 140,200])
upper_red = np.array([180, 255, 255])
frame = cv.imread('/home/bhavya/Pictures/task 1.png')
image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
   
blue_mask = cv.inRange(image, lower_blue, upper_blue)
green_mask = cv.inRange(image, lower_green, upper_green)
red_mask = cv.inRange(image, lower_red, upper_red)

contours, hierarchy = cv.findContours(blue_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
for pic, contour in enumerate(contours):
    area = cv.contourArea(contour)
    if(area > 300):
        x, y, a, b = cv.boundingRect(contour)
        frame = cv.rectangle(frame, (x, y), (x + a, y + b), (180, 0, 0), 2)
        M = cv.moments(contour)
        cx = int(M["m10"] / M["m00"])
        cy = int(M["m01"] / M["m00"])
        cv.circle(frame, (cx, cy), 2, (255, 255, 255), -1)
        cv.putText(frame, "blue color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(180, 0, 0)) 
             
print(x + a, y + b)   
contours, hierarchy = cv.findContours(green_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
for pic, contour in enumerate(contours):
    area = cv.contourArea(contour)
    if(area > 300):
        x, y, a, b = cv.boundingRect(contour)
        frame = cv.rectangle(frame, (x, y), (x + a, y + b), (0, 255, 0), 2)
        M = cv.moments(contour)
        cx = int(M["m10"] / M["m00"])
        cy = int(M["m01"] / M["m00"])
        cv.circle(frame, (cx, cy), 2, (255, 255, 255), -1)
        cv.putText(frame, "yellow color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 255, 0)) 
print(x + a, y + b)
contours, hierarchy = cv.findContours(red_mask, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
      
for pic, contour in enumerate(contours):
    area = cv.contourArea(contour)
    if(area > 300):
        x, y, a, b = cv.boundingRect(contour)
        frame = cv.rectangle(frame, (x, y), (x + a, y + b), (0, 0, 255), 2)
        M = cv.moments(contour)
        cx = int(M["m10"] / M["m00"])
        cy = int(M["m01"] / M["m00"])
        cv.circle(frame, (cx, cy), 2, (255, 255, 255), -1)
        cv.putText(frame, "green color", (x, y), cv.FONT_HERSHEY_SIMPLEX, 1.0,(0, 0, 255)) 

cv.imshow("normal image", frame)
print(x + a, y + b)

    
if cv.waitKey(1) & 0xFF == ord('q'):
    exit
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-2edd76a7d6f6> in <module>
#       9 upper_red = np.array([180, 255, 255])
#      10 frame = cv.imread('/home/bhavya/Pictures/fuk.png')
# ---> 11 image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
#      12
#      13 blue_mask = cv.inRange(image, lower_blue, upper_blue)
#
# error: OpenCV(4.5.2) /tmp/pip-req-build-rcdoave0/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import numpy as np
import cv2 as cv
framewidth = 640
framewigth = 480
img = cv.imread('/home/bhavya/Documents/5.png')
# cap.set(3, framewidth)
# cap.set(4, framewigth)

def empty(a):
    pass

cv.namedWindow("Parameters")
cv.resizeWindow("Parameters", 640, 240)
cv.createTrackbar("threshold1", "Parameters", 49, 255, empty)
cv.createTrackbar("threshold2", "Parameters", 140, 255, empty)

def getContours(img, imgContours):
    contours, hierarchy = cv.findContours(img, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)
    for cnt in contours:
        area = cv.contourArea(cnt)
        if area>= 2000:
            cv.drawContours(imgContours, cnt, -1, (255, 0, 255), 7)

while True:

    # success, img = cap.read()
    imgContour = img.copy()

    imgBlur = cv.GaussianBlur(img, (7,7), 1)
    imgGray = cv.cvtColor(imgBlur, cv.COLOR_BGR2GRAY)

    threshold1 = cv.getTrackbarPos("threshold1", "Parameters")
    threshold2 = cv.getTrackbarPos("threshold2", "Parameters")
    imgCanny = cv.Canny(imgGray, threshold1, threshold2)
    kernel = np.ones((5, 5))
    imgOil = cv.dilate(imgCanny, kernel, iterations = 1)

    getContours(imgOil, imgContour)

    cv.imshow("Contours", imgContour)
    cv.imshow("result", img)
    if cv.waitKey(1) == ord('q'):
        break
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-b7e6f59dc185> in <module>
#      25
#      26     # success, img = cap.read()
# ---> 27     imgContour = img.copy()
#      28
#      29     imgBlur = cv.GaussianBlur(img, (7,7), 1)
#
# AttributeError: 'NoneType' object has no attribute 'copy'

# %%
import numpy as np
import cv2


original_image = cv2.imread('/home/bhavya/Documents/test.jpg', cv2.IMREAD_COLOR)
gray_original = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
background_image = cv2.imread('/home/bhavya/Documents/test 2.jpg', cv2.IMREAD_COLOR)
gray_background = cv2.cvtColor(background_image, cv2.COLOR_BGR2GRAY)

foreground = np.absolute(gray_original - gray_background)
foreground[foreground > 0] = 255

cv2.imshow('Original Image', foreground)
cv2.waitKey(0)
# Out:
# 113

# %%
import cv2 as cv
import numpy as np

# lower_blue = np.array([100,60,100])
# upper_blue = np.array([180,255,255])greenLower = ()
#greenUpper = (64, 255, 255)
lower_red = np.array([50,10,20])
upper_red = np.array([150, 150, 250])
while(1):
    frame = cv.imread(cv.samples.findFile("/home/bhavya/Documents/kuf4.jpg"))
    blurred = cv.GaussianBlur(frame, (11, 11), 0)
    image = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
    blue_mask = cv.inRange(blurred, lower_red, upper_red)
    # green_mask = cv.inRange(image, lower_green, upper_green)
    contours, hierarchy = cv.findContours(blue_mask, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
    if len(contours) != 0:
         for contour in contours:
             if cv.contourArea(contour) > 500:
                 x,y,w,h = cv.boundingRect(contour)
                 cv.rectangle(image, (x,y), (x + w, y+h), (0,60,255), 3)
    cv.imshow("mask", blue_mask)
    cv.imshow("normal image", frame)
    
    if cv.waitKey(1) == ord('q'):
        break
cv.destroyAllWindows()

# %%
import rospy
import cv2 as cv
import numpy as np
from std_msgs.msg import String
def imag():
    img=cv.imread('/home/bhavya/Pictures/task 1.png')
    img2=img.copy()
    img=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    t1=cv.imread('/home/bhavya/Pictures/red.png')
    t2=cv.imread('/home/bhavya/Pictures/green.png')
    t3=cv.imread('/home/bhavya/Pictures/yellow.png')
    t1=cv.cvtColor(t1,cv.COLOR_BGR2GRAY)
    t2=cv.cvtColor(t2,cv.COLOR_BGR2GRAY)
    t3=cv.cvtColor(t3,cv.COLOR_BGR2GRAY)
    w,h=t1.shape[::-1]
    w,h=t2.shape[::-1]
    w,h=t3.shape[::-1]
    # for red bouy
    meth=cv.matchTemplate(img,t1,cv.TM_CCORR_NORMED)
    min_val,max_val,min_loc,max_loc=cv.minMaxLoc(meth)
    top_left=max_loc
    bottom_right=(top_left[0]+w,top_left[1]+h)
    img2=cv.rectangle(img2,top_left,bottom_right,(0,0,255),2)
    '''M=cv.moments(meth)
    w=int(M("m10")/M("m00"))
    h=int(M("m01")/M("m00"))'''
    cv.circle(img2,((top_left[0]+31,top_left[1]+42)),2,(255,255,255),-1)
    print("Red:",top_left,bottom_right)
    a = f' The Red Centre  : {top_left[0] + 35}, {top_left[1]+40}'
    cv.putText(img2,"Redcolor",max_loc,cv.FONT_HERSHEY_SIMPLEX,0.4,(0,0,255))
    #for green bouy 
    meth2=cv.matchTemplate(img,t2,cv.TM_CCORR_NORMED)
    min_val,max_val,min_loc,max_loc=cv.minMaxLoc(meth2)
    top_left=max_loc
    bottom_right=(top_left[0]+w,top_left[1]+h)
    img2=cv.rectangle(img2,top_left,bottom_right,(0,255,0),2)
    cv.circle(img2,((top_left[0]+35,top_left[1]+40)),2,(255,255,255),-1)
    print("Green:",top_left,bottom_right)
    b = f' The green Centre  : {top_left[0] + 35}, {top_left[1]+40}'
    cv.putText(img2,"Greencolor",max_loc,cv.FONT_HERSHEY_SIMPLEX,0.4,(0,255,0))
    #for yellow bouy
    meth3=cv.matchTemplate(img,t3,cv.TM_CCORR_NORMED)
    min_val,max_val,min_loc,max_loc=cv.minMaxLoc(meth3)
    top_left=max_loc
    bottom_right=(top_left[0]+w,top_left[1]+h)
    img2=cv.rectangle(img2,top_left,bottom_right,(0,255,255),2)
    cv.circle(img2,((top_left[0]+35,top_left[1]+40)),2,(255,255,255),-1)
    print("Yellow:",top_left,bottom_right)
    c = f' The yellow Centre  : {top_left[0] + 35}, {top_left[1]+40}'
    cv.putText(img2,"Yellowcolor",max_loc,cv.FONT_HERSHEY_SIMPLEX,0.4,(0,255,255))
    data = a, b, c
    return img2, data;


def talker():
    pub = rospy.Publisher('chatter', String, queue_size=1000)
    rospy.init_node('talker', anonymous=True)
    
    msg,img=imag()

    #rate = rospy.Rate(10) # 10hz
    while not rospy.is_shutdown():
        hello_str = f"{msg} %s"% rospy.get_time()
        rospy.loginfo(img)
        pub.publish(hello_str)
        #rate.sleep()

if __name__ == '__main__':
    try:
        talker()
    except rospy.ROSInterruptException:
        pass
