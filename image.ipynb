# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(vid)
if not cap.isOpened():
    print("Cannot open camera")
    exit()
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    # Display the resulting frame
    cv.imshow('bhavya', gray)
    if cv.waitKey(1) == ord('q'):
        break
# When everything done, release the capture
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# reading and showing a image

# %%
import cv2 as cv
import sys
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
if img is None:
    sys.exit("could not read image")
cv.imshow("image",imgs)
k = cv.waitKey(0)
if k == ord("q"):
    cv.imwrite("wp1913264-jarvis-wallpapers.png", img)
cv.destroyAllWindows()

# %% [markdown]
# image resize

# %%
import cv2 as cv
import sys
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
imgs = cv.resize(img, (1200, 1000))
if img is None:
    sys.exit("could not read image")
cv.imshow("image",imgs)
k = cv.waitKey(0)
if k == ord("q"):
    cv.imwrite("wp1913264-jarvis-wallpapers.png", img)
cv.destroyAllWindows()

# %% [markdown]
# Image slideshow

# %%
import os

# %%
img_names = os.listdir ('/home/bhavya/Pictures')
img_names
# Out:
# ['page 4.png',
#  'Screenshot from 2021-04-13 11-23-46.png',
#  'youtube trial 1.png',
#  'Screenshot from 2021-04-13 11-52-53.png',
#  'Screenshot from 2021-04-13 21-43-13.png',
#  'Screenshot from 2021-04-13 11-54-08.png',
#  'Screenshot from 2021-04-13 11-54-53.png',
#  'youtube 2.png',
#  'page 3.png',
#  'Screenshot from 2021-04-13 11-29-49.png',
#  'Screenshot from 2021-04-13 11-35-07.png',
#  'Screenshot from 2021-04-13 11-32-29.png',
#  'youtube 3.png',
#  'youtube 4.png',
#  'Screenshot from 2021-04-12 22-22-27.png',
#  'page 2.png',
#  'page 5.png',
#  'Screenshot from 2021-04-11 15-47-24.png',
#  'Screenshot from 2021-04-13 11-53-26.png',
#  'logo.png',
#  'Screenshot from 2021-04-13 11-31-18.png',
#  'page 1.png',
#  'Screenshot from 2021-04-09 16-04-57.png',
#  'Screenshot from 2021-04-14 00-09-21.png',
#  'Screenshot from 2021-04-13 21-40-52.png',
#  'Screenshot from 2021-04-13 22-06-47.png',
#  'Screenshot from 2021-04-13 11-54-27.png',
# ...

# %%
import cv2 as cv
import os

path = r'/home/bhavya/Pictures//'
img_names = os.listdir('/home/bhavya/Pictures/')
for img_name in img_names:
    img = cv.imread(path + img_name)
    imgv = cv.resize(img, (600, 400))
    cv.imshow('image', imgv)
    k = cv.waitKey(0)
    if k == ord('q'):
        exit()
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-b4b080f9b475> in <module>
#       6 for img_name in img_names:
#       7     img = cv.imread(path + img_name)
# ----> 8     imgv = cv.resize(img, (600, 400))
#       9     cv.imshow('image', imgv)
#      10     k = cv.waitKey(0)
#
# error: OpenCV(4.2.0) ../modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# image combination

# %%
import cv2 as cv
import numpy as mp
img1 = cv.imread('/home/bhavya/Pictures//logo.png')
img2 = cv.imread('/home/bhavya/Pictures//youtube 4.png')
img_1 = cv.resize(img1, (600, 400))
img_2 = cv.resize(img2, (600, 400))
dst = cv.addWeighted(img_1,0.3,img_2,0.7,0)
cv.imshow('dst',dst)
k = cv.waitKey(0)
if k == ord('q'):
    exit()
cv.destroyAllWindows()

# %% [markdown]
# adding line on an image

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
img_resize = cv.resize(img, (1280,720))
pt1 = (500, 350)
pt2 = (800, 350)
color = (23,200,54)
thickness = 3
cv.line(img_resize, pt1, pt2, color, thickness)
cv.imshow("line image", img_resize)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# #DROW A RECANGLE ON A IMAGE

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
img_resize = cv.resize(img, (1280,720))
pt1 = (500, 50)
pt2 = (800, 350)
color = (23,200,54)
thickness = 3
linetype = cv.LINE_4
cv.rectangle(img_resize, pt1, pt2, color, thickness, linetype)
cv.imshow("rectangle  image", img_resize)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# #DRAW A CIRCLE

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
img_resize = cv.resize(img, (1280,720))
pt1 = (650, 200)
pt2 = 180
color = (23,200,54)
thickness = 3
linetype = cv.LINE_4
cv.circle(img_resize, pt1, pt2, color, thickness, linetype)
cv.imshow("circle image", img_resize)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# #DRAW ELLIPSE

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
img_resize = cv.resize(img, (1280,720))
center = (650, 200)
axis = (150, 250)
angle = 35
startangle = 0
endangle = 360
color = (23,200,50)
cv.ellipse(img_resize, center, axis, angle, startangle, endangle, color)
cv.imshow("ELLIPS image", img_resize)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# #DRAW POLYGON

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
img_resize = cv.resize(img, (1280,720))
ptr = np.array([[800,345], [800,40], [500,40], [500,345], [645,570]])
isclosed = True
color = (23,200,50)
thickness = 5
cv.polylines(img_resize, [ptr], isclosed, color, thickness)
cv.imshow("POLYGON image", img_resize)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# #PUT TEXT

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
img_resize = cv.resize(img, (1280,720))
text = "iron man"
org = (500,600)
font = cv.FONT_HERSHEY_COMPLEX
fontscale = 2
color = (23,200,50)
cv.putText(img_resize, text, org, font, fontscale, color)
isclosed = True
color = (23,200,50)
thickness = 5
cv.polylines(img_resize, [ptr], isclosed, color, thickness)img[100,100] = [255,255,255]
>>> print( img[100,100] )
[255 255 255]
cv.imshow("POLYGON image", img_resize)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# MAKING VIDEO FROM IMAGES

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')

# %% [markdown]
# BITWISE OPERATIONS

# %%
import cv2 as cv

img1 = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
img2 = cv.imread('/home/bhavya/Pictures/logo.png')
# I want to put logo on top-left corner, So I create a ROI
rows,cols,channels = img2.shape
roi = img1[0:rows, 0:cols]
# Now create a mask of logo and create its inverse mask also
img2gray = cv.cvtColor(img2,cv.COLOR_BGR2GRAY)
ret, mask = cv.threshold(img2gray, 10, 255, cv.THRESH_BINARY)
mask_inv = cv.bitwise_not(mask)
# Now black-out the area of logo in ROI
img1_bg = cv.bitwise_and(roi,roi,mask = mask_inv)
# Take only region of logo from logo image.
img2_fg = cv.bitwise_and(img2,img2,mask = mask)

dst = cv.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst
cv.imshow('res',img1)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Scaling

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
res = cv.resize(img, None, fx=2, fy=2, interpolation = cv.INTER_CUBIC)
cv.imshow('img', res)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Translation

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
rows,cols = img.shape
M = np.float32([[1,0,100],[0,1,50]])
dst = cv.warpAffine(img,M,(cols,rows))
cv.imshow('img',dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Rotation

# %%
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
rows,cols = img.shape
M = cv.getRotationMatrix2D(((cols-1)/2.0,(rows-1)/2.0),90,1)
dst = cv.warpAffine(img,M,(cols,rows))
cv.imshow('img',dst)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Erosion

# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
kernel = np.ones((5,5),np.uint8)
erosion = cv.erode(img,kernel,iterations = 1)
cv.imshow('img',erosion)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Dilation

# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
kernel = np.ones((5,5),np.uint8)
dilation = cv.dilate(img,kernel,iterations = 1)
cv.imshow('img',dilation)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Opening

# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
kernel = np.ones((5,5),np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
cv.imshow('img',opening)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Closing

# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
kernel = np.ones((5,5),np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
cv.imshow('img',closing)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Morphological Gradient

# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
kernel = np.ones((5,5),np.uint8)
gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
cv.imshow('img',gradient)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Top Hat

# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
kernel = np.ones((5,5),np.uint8)
tophat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
cv.imshow('img',tophat)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Black Hat

# %%
import cv2 as cv
import numpy as np
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)import cv2 as cv
import numpy as np
kernel = np.ones((5,5),np.uint8)
blackhat = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)
cv.imshow('img',blackhat)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Simple Thresholding

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
ret,thresh1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
ret,thresh2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
ret,thresh3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
ret,thresh4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
ret,thresh5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# Adaptive Thresholding

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
img = cv.medianBlur(img,5)
ret,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
th2 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_MEAN_C,\
            cv.THRESH_BINARY,11,2)
th3 = cv.adaptiveThreshold(img,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# Otsu's Binarization

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
# global thresholding
ret1,th1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv.threshold(img,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv.GaussianBlur(img,(5,5),0)
ret3,th3 = cv.threshold(blur,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# 2D Convolution ( Image Filtering )

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
kernel = np.ones((5,5),np.float32)/25
dst = cv.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Image Blurring (Image Smoothing)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
blur = cv.blur(img,(5,5))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Gaussian Blurring

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
blur = cv.GaussianBlur(img,(5,5),0)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
#  Median Blurring

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
median = cv.medianBlur(img,5)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Bilateral Filtering

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png')
blur = cv.bilateralFilter(img,9,75,75)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Canny Edge Detection in OpenCV

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
edges = cv.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Plotting Histograms
# Using Matplotlib

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
plt.hist(img.ravel(),256,[0,256]) 
plt.show()

# %% [markdown]
# Plotting Histograms
# Using OpenCV

# %%
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
mask = np.zeros(img.shape[:2], np.uint8)
mask[100:300, 100:400] = 255
masked_img = cv.bitwise_and(img,img,mask = mask)
hist_full = cv.calcHist([img],[0],None,[256],[0,256])
hist_mask = cv.calcHist([img],[0],mask,[256],[0,256])
plt.subplot(221), plt.imshow(img, 'gray')
plt.subplot(222), plt.imshow(mask,'gray')
plt.subplot(223), plt.imshow(masked_img, 'gray')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.xlim([0,256])
plt.show()

# %% [markdown]
# Histogram Equalization

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('/home/bhavya/Pictures/download.jpeg',0)
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# 2D Histogram in OpenCV

# %%
import numpy as np
import cv2 as cv
img = cv.imread('/home/bhavya/Pictures/download.jpeg')
hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
hist = cv.calcHist([hsv], [0, 1], None, [180, 256], [0, 180, 0, 256])
cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# Plotting 2D Histograms

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/download.jpeg')
hsv = cv.cvtColor(img,cv.COLOR_BGR2HSV)
hist = cv.calcHist( [hsv], [0, 1], None, [180, 256], [0, 180, 0, 256] )
plt.imshow(hist,interpolation = 'nearest')
plt.show()

# %% [markdown]
# Backprojection in OpenCV

# %%
import numpy as np
import cv2 as cv
roi = cv.imread('/home/bhavya/Pictures/download.jpeg')
hsv = cv.cvtColor(roi,cv.COLOR_BGR2HSV)
target = cv.imread('/home/bhavya/Pictures/download.jpeg')
hsvt = cv.cvtColor(target,cv.COLOR_BGR2HSV)
roihist = cv.calcHist([hsv],[0, 1], None, [180, 256], [0, 180, 0, 256] )
cv.normalize(roihist,roihist,0,255,cv.NORM_MINMAX)
dst = cv.calcBackProject([hsvt],[0,1],roihist,[0,180,0,256],1)
disc = cv.getStructuringElement(cv.MORPH_ELLIPSE,(5,5))
cv.filter2D(dst,-1,disc,dst)
ret,thresh = cv.threshold(dst,50,255,0)
thresh = cv.merge((thresh,thresh,thresh))
res = cv.bitwise_and(target,thresh)
res = np.vstack((target,thresh,res))
cv.imwrite('res.jpg',res)

# %% [markdown]
# Fourier Transform in Numpy

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/download.jpeg',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/home/bhavya/Pictures/wp1913264-jarvis-wallpapers.png',0)
rows, cols = img.shape
crow,ccol = rows//2 , cols//2
fshift[crow-30:crow+31, ccol-30:ccol+31] = 0
f_ishift = np.fft.ifftshift(fshift)
img_back = np.fft.ifft2(f_ishift)
img_back = np.real(img_back)
plt.subplot(131),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img_back, cmap = 'gray')
plt.title('Image after HPF'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Why Laplacian is a High Pass Filter?

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
mean_filter = np.ones((3,3))
x = cv.getGaussianKernel(5,10)
gaussian = x*x.T
scharr = np.array([[-3, 0, 3],
                   [-10,0,10],
                   [-3, 0, 3]])
sobel_x= np.array([[-1, 0, 1],
                   [-2, 0, 2],
                   [-1, 0, 1]])
sobel_y= np.array([[-1,-2,-1],
                   [0, 0, 0],
                   [1, 2, 1]])
laplacian=np.array([[0, 1, 0],
                    [1,-4, 1],
                    [0, 1, 0]])
filters = [mean_filter, gaussian, laplacian, sobel_x, sobel_y, scharr]
filter_name = ['mean_filter', 'gaussian','laplacian', 'sobel_x', \
                'sobel_y', 'scharr_x']
fft_filters = [np.fft.fft2(x) for x in filters]
fft_shift = [np.fft.fftshift(y) for y in fft_filters]
mag_spectrum = [np.log(np.abs(z)+1) for z in fft_shift]
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(mag_spectrum[i],cmap = 'gray')
    plt.title(filter_name[i]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# Object Tracking

# %%
import cv2 as cv
import numpy as np
while(1):
    frame = cv.imread('/home/bhavya/Pictures/SAE/earth day.png')
    hsv = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
    lower_blue = np.array([110,50,50])
    upper_blue = np.array([130,255,255])
    mask = cv.inRange(hsv, lower_blue, upper_blue)
    res = cv.bitwise_and(frame,frame, mask= mask)
    cv.imshow('frame',frame)
    cv.imshow('mask',mask)
    cv.imshow('res',res)
    k = cv.waitKey(5) & 0xFF
    if k == 27:
        break
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-45a9aaeac8ed> in <module>
#       4 while(1):
#       5     # # Take each frame
# ----> 6     frame = cv.imread('/home/bhavya/Pictures/SAE/earth day.png')
#       7     hsv = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
#       8     lower_blue = np.array([110,50,50])
#
# KeyboardInterrupt:

# %% [markdown]
# I solved problem. I play around with HoughCircles value 79, 23. And medianBlur to 11(odd number not even numbers)

# %%
import numpy as np
import cv2 as cv

    
    image = cv.imread('/home/bhavya/Pictures/task 1.png')
    img = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
    copy_img = image.copy()

    circles = cv.HoughCircles(img, cv.HOUGH_GRADIENT, 1, 10, np.array([]), 79, 23, 9, 26)

    counter = 0
    if circles is not None: 
        _a, b, _c = circles.shape
        for i in range(b):
            cv.circle(copy_img, (circles[0][i][0], circles[0][i][1]), 2, (0, 255, 0), 3, cv.LINE_AA)  
            counter += 1

        cv.imwrite('task 1.png', copy_img)
        cv.imshow('detected circles', copy_img)

    cv.imshow("source", image)
    cv.waitKey(0)
    cv.destroyAllWindows()
# Out:
#   File "<ipython-input-5-aa2512a83198>", line 5
#     image = cv.imread('/home/bhavya/Pictures/task 1.png')
#     ^
# IndentationError: unexpected indent
